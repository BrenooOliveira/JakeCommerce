# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.alert import Alert

# %%
options = Options() 
options.add_argument("--window-size=1440,900")
options.binary_location = "/usr/bin/brave-browser"

driver = webdriver.Chrome(options=options)


driver.get("http://localhost:8080/login")

# %% [markdown]
# #### Teste de Login
# Email de Login Inválido

# %%
email = driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[2]/form/div[1]/input")
email.click()
email.send_keys("email_invalidooo@gmail.com")

senha = driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[2]/form/div[2]/input")
senha.click()
senha.send_keys("Invalido123@")

botao = driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[2]/form/button")
botao.click()

# %% [markdown]
# #### Teste de Login
# Email de Login Inválido

# %%
email = driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[2]/form/div[1]/input")
email.click()
email.send_keys("breno@teste.com")

senha = driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[2]/form/div[2]/input")
senha.click()
senha.send_keys("SENHA INVALIDA")

botao = driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[2]/form/button")
botao.click()

# %% [markdown]
# #### Teste de Login
# Login com Sucesso

# %%
email = driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[2]/form/div[1]/input")
email.click()
email.send_keys("breno@teste.com")

senha = driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[2]/form/div[2]/input")
senha.click()
senha.send_keys("")

botao = driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[2]/form/button")
botao.click()

# %% [markdown]
# ### Teste de Carrinho
# Adicionar e Retirar Item do carrinho

# %%
# Adicionando Mais um Produto ao Carrinho

# clicando no botão de livros para ir até /livros
driver.find_element(By.XPATH, "/html/body/div[1]/nav/div/div/ul[1]/li[2]/a").click()

# %%
# Adicionando o primeiro livro ao carrinho
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[3]/div/table/tbody/tr[1]/td[6]/form/button").click()

# %%
# retirando o item do carrinho
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[2]/div[1]/div/div[2]/table/tbody/tr/td[5]/form/button").click()

# %% [markdown]
# Adicionar Mais de um Produto ao Carrinho

# %%
# clicando no botão de livros para ir até /livros
driver.find_element(By.XPATH, "/html/body/div[1]/nav/div/div/ul[1]/li[2]/a").click()

# %%
# Primeiro livro
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[3]/div/table/tbody/tr[1]/td[6]/form/button").click()

# %%
# clicar em "continuar comprando" para voltar para a página de livros
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[2]/div[2]/div[1]/div[2]/a").click()

# %%
# Segundo livro
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[3]/div/table/tbody/tr[2]/td[6]/form/button").click()

# %%
# Inserir o limite de livros (10) em um carrinho
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[2]/div[1]/div/div[2]/table/tbody/tr[1]/td[3]/form/div/input[2]").send_keys("100",Keys.ENTER)

# %%
# Prosseguir com o pagamento
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/div[2]/div[2]/div[1]/div[2]/button").click()

# %% [markdown]
# #### Teste do checkout

# %%
# Selecionar Endereços
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/form/div/div[1]/div[1]/div[2]/div/div/div/label[2]/input").click()

# %% [markdown]
# Pagando com mais de um cartão - Valor inválido (menos de 10 reais)

# %%
# clicando em cartões
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/form/div/div[1]/div[2]/div[2]/ul/li[2]/button").click()

# %%
# enviando valores inválidos para o cartão 1 - pagamento com mais de um cartão
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/form/div/div[1]/div[2]/div[2]/div/div[2]/div/div[2]/div[2]/div/input").send_keys("1")

# enviando valores inválidos para o cartão 2 - pagamento com mais de um cartão
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/form/div/div[1]/div[2]/div[2]/div/div[2]/div/div[3]/div[2]/div/input").send_keys("1")

# %%
# clicando em "Finalizar Compra" - Tentando finalizar a compra sem aceitar os termos de uso
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/form/div/div[2]/div/div[2]/button").click()

# %%
# Aceitando o alerta de termos de uso
Alert(driver).accept()

# %%
# Aceitando o termo de uso e tentando finalizar a compra novamente
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/form/div/div[2]/div/div[2]/div[6]/input").click()

# %%
# clicando em "Finalizar Compra"
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/form/div/div[2]/div/div[2]/button").click()

# %%
# Aceitando o alerta do valor incorreto de pagamento
Alert(driver).accept()

# %%
# Corrindo valores,

# enviando valores inválidos para o cartão 1 - pagamento com mais de um cartão
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/form/div/div[1]/div[2]/div[2]/div/div[2]/div/div[2]/div[2]/div/input").send_keys(Keys.CONTROL + "a")
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/form/div/div[1]/div[2]/div[2]/div/div[2]/div/div[2]/div[2]/div/input").send_keys("28.90")

# enviando valores inválidos para o cartão 2 - pagamento com mais de um cartão
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/form/div/div[1]/div[2]/div[2]/div/div[2]/div/div[3]/div[2]/div/input").send_keys(Keys.CONTROL + "a")
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/form/div/div[1]/div[2]/div[2]/div/div[2]/div/div[3]/div[2]/div/input").send_keys("20")

# %%
# clicando em "Finalizar Compra"
driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[2]/div/form/div/div[2]/div/div[2]/button").click()
